# %%
# Market Risk Project
# Hanna Gerguis DeLEpine
# ESILV – 2025-2026

import sys
import os

print("Python executable:", sys.executable)
print("Python version:", sys.version)
print("Working directory:", os.getcwd())
# Out:
# Python executable: C:\Users\matth\anaconda3\envs\Market_Risk_Project\python.exe
# Python version: 3.13.11 | packaged by Anaconda, Inc. | (main, Dec 10 2025, 21:21:58) [MSC v.1929 64 bit (AMD64)]
# Working directory: C:\Users\matth\OneDrive\PC Matthieu\ESILV\A4\S7_IF3\Drive_Matthieu\SPECIALIZATION IF\Market risk\MarketRisk_Project_Hanna_Gerguis_DeLEpine\notebooks
